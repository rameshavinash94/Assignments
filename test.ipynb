# %% [markdown]
# <a href="https://colab.research.google.com/github/rameshavinash94/Assignments/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install explainerdashboard
# !pip install pycaret

# %%
# load dataset
from pycaret.datasets import get_data
data = get_data('iris')
# init setup
from pycaret.classification import *
s = setup(data, target = 'species', session_id = 123)
# train model
lr = create_model('lr')
# generate dashboard
dashboard(lr,display_format='inline')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 1       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 2       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 3       0.9091  1.0000  0.9167  0.9318  0.9091  0.8642  0.8750
# 4       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 5       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 6       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 7       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 8       1.0000  1.0000  1.0000  1.0000  1.0000  1.0000  1.0000
# 9       0.7000  0.9214  0.6944  0.6900  0.6867  0.5385  0.5471
# Mean    0.9609  0.9921  0.9611  0.9622  0.9596  0.9403  0.9422
# SD      0.0911  0.0236  0.0923  0.0930  0.0949  0.1399  0.1369
# WARNING: For shap='linear', shap interaction values can unfortunately not be calculated!
# ...
